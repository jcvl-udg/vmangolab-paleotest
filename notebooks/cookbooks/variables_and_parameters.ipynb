# %% [markdown]
# ## Exploring parameters and variables
#
# Parameters as assumed being somewhat static. But for certain use-cases (sensitivity analysis, calibration) it might be necessary to
# explore the parameter space. This can be achived by 'wrapping', inheriting from a process and implementing parameters (present in parameter toml files) as variables.

# %%
import numpy as np
import pandas as pd
import igraph as ig
import xsimlab as xs
import xarray as xr
import vmlab
from vmlab.models import fruit_model

# %%
from vmlab.processes.carbon_demand import CarbonDemand

# create a new process and change parameter into variabl
        
@xs.process
class CarbonDemandTest(CarbonDemand):
    RGR_fruit_ini = xs.variable()
    def initialize(self):
        super(CarbonDemandTest, self).initialize()
        # overwrite a parameter from carbon_demand.toml
        self.parameters.RGR_fruit_ini = self.RGR_fruit_ini

# %%
fruit_model = fruit_model.update_processes({
    'carbon_demand': CarbonDemandTest
}).drop_processes('fruit_quality')

# %%
tree = pd.read_csv('../../vmlab/data/trees/branch_G3.csv')
small_branch = tree[tree.id < 18] # just two fruits

# %%
# use a custom weather file
wheater = pd.read_csv(
    '../../vmlab/data/environment/smartis_lingne_paradis_01.2002_01.2008.csv',
    sep=';', parse_dates=['Jour'], dayfirst=True
)
wheater = wheater[wheater.Jour <= '2003-06-01'] # drop some rows
wheater.to_csv('tmp/weather.csv', sep=';')

# %%
setup = vmlab.create_setup(
    model=fruit_model,
    tree=small_branch,
    start_date='2002-06-01',
    end_date='2003-06-01',
    setup_toml='fruit_model_branch.toml',
    current_cycle=3,
    input_vars={
        'growth__leaf_senescence_enabled': False,
        'environment__weather_file': 'tmp/weather.csv'
    },
    output_vars={
        'carbon_allocation__D_fruit': 'day',
        'phenology__fruit_growth_tts_delta': 'day',
        'environment__TM_day': 'day'
    }
)

# %%
# change one or more variables and run the model with each set of variables.
# Since the process 'CarbonDemandTest' is declared inside a notebook batch mode, prallelization does not work
RGR_fruit_ini = [x for x in np.linspace(0.0105, 0.0205, 5)]
dss = xr.concat([
    vmlab.run(setup.xsimlab.update_vars(fruit_model, {
        'carbon_demand__RGR_fruit_ini': x
    }), fruit_model) for x in RGR_fruit_ini
], dim=xr.IndexVariable('RGR_fruit_ini', RGR_fruit_ini))
dss
# Out:
#              0% | initialize
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # change one or more variables and run the model with each set of variables.
#       2 # Since the process 'CarbonDemandTest' is declared inside a notebook batch mode, prallelization does not work
#       3 RGR_fruit_ini = [x for x in np.linspace(0.0105, 0.0205, 5)]
# ----> 4 dss = xr.concat([
#       5     vmlab.run(setup.xsimlab.update_vars(fruit_model, {
#       6         'carbon_demand__RGR_fruit_ini': x
#       7     }), fruit_model) for x in RGR_fruit_ini
#       8 ], dim=xr.IndexVariable('RGR_fruit_ini', RGR_fruit_ini))
#       9 dss
#
# Cell In[22], line 5, in <listcomp>(.0)
#       1 # change one or more variables and run the model with each set of variables.
#       2 # Since the process 'CarbonDemandTest' is declared inside a notebook batch mode, prallelization does not work
#       3 RGR_fruit_ini = [x for x in np.linspace(0.0105, 0.0205, 5)]
#       4 dss = xr.concat([
# ----> 5     vmlab.run(setup.xsimlab.update_vars(fruit_model, {
#       6         'carbon_demand__RGR_fruit_ini': x
#       7     }), fruit_model) for x in RGR_fruit_ini
#       8 ], dim=xr.IndexVariable('RGR_fruit_ini', RGR_fruit_ini))
#       9 dss
#
# File ~\Documents\GitHub\vmangolab-paleotest\vmlab\vmlab.py:536, in run(dataset, model, progress, geometry, batch, store, hooks, nb_proc, verbosity)
#     534         ds = _run_parallel(dataset, model, store, batch, sw, scenes, positions, progress, nb_proc)
#     535 else:
# --> 536     ds = dataset.xsimlab.run(model=model, decoding={'mask_and_scale': False}, hooks=hooks, store=store)
#     538 return _cleaup_dataset(ds)
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\xr_accessor.py:823, in SimlabAccessor.run(self, model, batch_dim, check_dims, validate, store, encoding, decoding, hooks, parallel, scheduler, safe_mode)
#     807     model = model.clone()
#     809 driver = XarraySimulationDriver(
#     810     self._ds,
#     811     model,
#    (...)
#     820     scheduler=scheduler,
#     821 )
# --> 823 driver.run_model()
#     825 return driver.get_results()
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\drivers.py:472, in XarraySimulationDriver.run_model(self)
#     469 args = (self.store, self.hooks, self._validate_option)
#     471 if self.batch_dim is None:
# --> 472     _run(
#     473         ds_in,
#     474         self.model,
#     475         *args,
#     476         parallel=self.parallel,
#     477         scheduler=self.scheduler,
#     478     )
#     480 else:
#     481     ds_gby_batch = ds_in.groupby(self.batch_dim)
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\drivers.py:336, in _run(dataset, model, store, hooks, validate, batch, batch_size, parallel, scheduler)
#     333 model.update_state(in_vars, validate=validate_inputs, ignore_static=True)
#     335 try:
# --> 336     model.execute("initialize", rt_context, **execute_kwargs)
#     338     for step, (_, ds_step) in enumerate(ds_gby_steps):
#     340         rt_context.update(
#     341             step=step,
#     342             step_start=ds_step["_clock_start"].values,
#     343             step_end=ds_step["_clock_end"].values,
#     344             step_delta=ds_step["_clock_diff"].values,
#     345         )
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\model.py:1023, in Model.execute(self, stage, runtime_context, hooks, validate, parallel, scheduler)
#    1021 else:
#    1022     for p_obj in self._processes.values():
# -> 1023         _, (_, signal_process) = self._execute_process(p_obj, *execute_args)
#    1025         if signal_process == RuntimeSignal.BREAK:
#    1026             break
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\model.py:842, in Model._execute_process(self, p_obj, stage, runtime_context, hooks, validate, state)
#     839 if signal_pre.value > 0:
#     840     return p_name, ({}, signal_pre)
# --> 842 state_out, signal_out = executor.execute(
#     843     p_obj, stage, runtime_context, state=state
#     844 )
#     846 signal_post = self._call_hooks(hooks, runtime_context, stage, "process", "post")
#     847 if signal_post.value > signal_out.value:
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\process.py:530, in _ProcessExecutor.execute(self, p_obj, stage, runtime_context, state)
#     528     return {}, RuntimeSignal.NONE
#     529 else:
# --> 530     signal_out = executor.execute(p_obj, runtime_context, state=state)
#     532     skeys = [p_obj.__xsimlab_state_keys__[k] for k in self.out_vars]
#     533     sobj = p_obj.__xsimlab_state__
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\xsimlab\process.py:394, in _RuntimeMethodExecutor.execute(self, p_obj, runtime_context, state)
#     390     p_obj.__xsimlab_state__ = state
#     392 args = [runtime_context[k] for k in self.args]
# --> 394 signal = self.meth(p_obj, *args)
#     396 if signal is None:
#     397     return RuntimeSignal.NONE
#
# File ~\Documents\GitHub\vmangolab-paleotest\vmlab\processes\environment.py:104, in Environment.initialize(self)
#     100 # smartis may have nans
#     101 self.weather_hourly_df.bfill(inplace=True)
#     103 self.weather_daily_df = pd.DataFrame({
# --> 104     'TM': self.weather_hourly_df['TM'].groupby(pd.Grouper(freq="1D")).mean(),
#     105     'GR': self.weather_hourly_df['GR'].groupby(pd.Grouper(freq="1D")).mean(),
#     106     'RH': self.weather_hourly_df['RH'].groupby(pd.Grouper(freq="1D")).mean()
#     107 }).astype(np.float32)
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\pandas\core\series.py:2131, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2128     raise TypeError("as_index=False only valid with DataFrame")
#    2129 axis = self._get_axis_number(axis)
# -> 2131 return SeriesGroupBy(
#    2132     obj=self,
#    2133     keys=by,
#    2134     axis=axis,
#    2135     level=level,
#    2136     as_index=as_index,
#    2137     sort=sort,
#    2138     group_keys=group_keys,
#    2139     observed=observed,
#    2140     dropna=dropna,
#    2141 )
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\pandas\core\groupby\grouper.py:895, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     893 # a passed-in Grouper, directly convert
#     894 if isinstance(key, Grouper):
# --> 895     grouper, obj = key._get_grouper(obj, validate=False)
#     896     if key.key is None:
#     897         return grouper, frozenset(), obj
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\pandas\core\resample.py:2170, in TimeGrouper._get_grouper(self, obj, validate)
#    2166 def _get_grouper(
#    2167     self, obj: NDFrameT, validate: bool = True
#    2168 ) -> tuple[BinGrouper, NDFrameT]:
#    2169     # create the resampler and return our binner
# -> 2170     r = self._get_resampler(obj)
#    2171     return r.grouper, cast(NDFrameT, r.obj)
#
# File c:\Users\jcarlos.vargas\AppData\Local\anaconda3\envs\vmango-lab\lib\site-packages\pandas\core\resample.py:2160, in TimeGrouper._get_resampler(self, obj, kind)
#    2151 elif isinstance(ax, TimedeltaIndex):
#    2152     return TimedeltaIndexResampler(
#    2153         obj,
#    2154         timegrouper=self,
#    (...)
#    2157         gpr_index=ax,
#    2158     )
# -> 2160 raise TypeError(
#    2161     "Only valid with DatetimeIndex, "
#    2162     "TimedeltaIndex or PeriodIndex, "
#    2163     f"but got an instance of '{type(ax).__name__}'"
#    2164 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
dss.where(dss.carbon_allocation__D_fruit > 0, drop=True).carbon_allocation__D_fruit.plot(hue='RGR_fruit_ini', col='GU', figsize=(12, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dss.where(dss.carbon_allocation__D_fruit > 0, drop=True).carbon_allocation__D_fruit.plot(hue='RGR_fruit_ini', col='GU', figsize=(12, 5))
#
# NameError: name 'dss' is not defined
